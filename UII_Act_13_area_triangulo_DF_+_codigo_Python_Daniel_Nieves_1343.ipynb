# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielNieves128/EPPL-rea-de-un-Triangulo-rect-ngulo/blob/main/UII_Act_13_area_triangulo_DF_%2B_codigo_Python_Daniel_Nieves_1343.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Daniel Nieves NL = 41 Fecha 25/03/26 ☣
# ---
# ## Calcular area de un triangulo
# ---
# ![](https://raw.githubusercontent.com/DanielNieves128/EPPL-rea-de-un-Triangulo-rect-ngulo/refs/heads/main/Area%20de%20triangulo.PNG)
#
# ---
# ## formula para sacar area
# A = b*h/2
# # datos de entrada
# $b$ ?,
# $h$ ?
# # diagrama de flujo
# ![](https://raw.githubusercontent.com/DanielNieves128/EPPL-rea-de-un-Triangulo-rect-ngulo/refs/heads/main/diagrama%20tirangulo.PNG)

# %%
# calcular el area de un triangulo
# variables de A, b, h,
# formulas A = b * h / 2
#capturar el valor de A
import math
print("calcular Area del Triangulo")
h =float(input("ingrese la altura: "))
b =float(input("ingrese la base: "))
A = b * h / 2
print("el area del triangulo es: ", A)
print("Daniel Nieves NL = 41")
# Out:
# calcular Area del Triangulo
# ingrese la altura: 8
# ingrese la base: 4
# el area del triangulo es:  16.0
# Daniel Nieves NL = 41

# %% [markdown]
# ## relacion entre codigo y diagrama
# ![](https://raw.githubusercontent.com/DanielNieves128/EPPL-rea-de-un-Triangulo-rect-ngulo/refs/heads/main/AREA%20DE%20TRIANGULO%201.png)
